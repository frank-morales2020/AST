# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/AST/blob/main/3CASES_TOPO_AGENTIC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://huggingface.co/frankmorales2020/topo-gemma-4-e4b-vision-13tasks

# %% [markdown]
# ## SETUP

# %%
# !pip install -q transformers torch openai python-dotenv pyyaml requests numpy pydantic fastapi uvicorn
# !pip install -U bitsandbytes>=0.46.1 -q
# !pip install unsloth -q

# %%
# !pip show transformers torch unsloth bitsandbytes
# Out:
# Name: transformers
# Version: 5.5.0
# Summary: Transformers: the model-definition framework for state-of-the-art machine learning models in text, vision, audio, and multimodal models, for both inference and training.
# Home-page: https://github.com/huggingface/transformers
# Author: The Hugging Face team (past and future) with the help of all our contributors (https://github.com/huggingface/transformers/graphs/contributors)
# Author-email: transformers@huggingface.co
# License: Apache 2.0 License
# Location: /usr/local/lib/python3.13/dist-packages
# Requires: huggingface-hub, numpy, packaging, pyyaml, regex, safetensors, tokenizers, tqdm, typer
# Required-by: peft, sentence-transformers, trl, unsloth, unsloth_zoo
# ---
# Name: torch
# Version: 2.11.0+cu128
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org
# Author:
# Author-email: PyTorch Team <packages@pytorch.org>
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.13/dist-packages
# Requires: cuda-bindings, cuda-toolkit, filelock, fsspec, jinja2, networkx, nvidia-cudnn-cu12, nvidia-cusparselt-cu12, nvidia-nccl-cu12, nvidia-nvshmem-cu12, setuptools, sympy, triton, typing-extensions
# Required-by: accelerate, bitsandbytes, cut-cross-entropy, fastai, peft, sentence-transformers, timm, torchdata, torchvision, unsloth, unsloth_zoo, xformers
# ---
# Name: unsloth
# Version: 2026.8.19
# Summary: 2-5X faster training, reinforcement learning & finetuning
# Home-page: https://unsloth.ai
# Author: Unsloth AI team
# Author-email: info@unsloth.ai
# License:
# Location: /usr/local/lib/python3.13/dist-packages
# Requires: accelerate, bitsandbytes, click, datasets, diffusers, hf_transfer, huggingface_hub, nest-asyncio, numpy, packaging, peft, protobuf, psutil, pydantic, pyyaml, rich, sentencepiece, structlog, torch, torchvision, tqdm, transformers, triton, trl, typer, tyro, unsloth_zoo, wheel, xformers
# Required-by:
# ---
# Name: bitsandbytes
# Version: 0.50.1
# Summary: k-bit optimizers and matrix multiplication routines.
# Home-page: https://github.com/bitsandbytes-foundation/bitsandbytes
# Author:
# Author-email: Tim Dettmers <dettmers@cs.washington.edu>
# License:
# Location: /usr/local/lib/python3.13/dist-packages
# Requires: numpy, packaging, torch
# Required-by: unsloth

# %%
import sys
import os
import contextlib
from PIL import Image

# 1. Download image using wget and load it
image_url = "https://picsum.photos/300/300"
image_filename = "test_image.jpg"
os.system(f"wget -q -O {image_filename} {image_url}")

image = Image.open(image_filename).convert("RGB")

# %%
import sys
import os
import contextlib
import torch
from huggingface_hub import hf_hub_download
from PIL import Image
from unsloth import FastVisionModel  # Will now work!

# ============================================================================
# YOUR EXACT GEMMA CODE
# ============================================================================

@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

os.environ["UNSLOTH_DISABLE_LOGGING"] = "1"
os.environ["TRANSVERSE_NO_PROGRESS_BARS"] = "1"
os.environ["TQDM_DISABLE"] = "1"

original_torch_load = torch.load
def patched_torch_load(*args, **kwargs):
    kwargs["weights_only"] = False
    return original_torch_load(*args, **kwargs)
torch.load = patched_torch_load

print("="*80)
print("👁️ GEMMA-4-E4B-VISION - TOPO-2026 CERTIFIED (13 TASKS)")
print("="*80)

MODEL_ID = "frankmorales2020/topo-gemma-4-e4b-vision-13tasks"

with suppress_all_output():
    ckpt_path = hf_hub_download(repo_id=MODEL_ID, filename="pytorch_model.bin")
    checkpoint = torch.load(ckpt_path, map_location="cpu")
    BASE_MODEL = checkpoint.get("base_model", "frankmorales2020/gemma-4-e4b-unesco-optimized")

    model, tokenizer = FastVisionModel.from_pretrained(
        model_name=BASE_MODEL,
        load_in_4bit=True,
        dtype=torch.bfloat16,
    )
    FastVisionModel.for_inference(model)

print("\n✅ Gemma-4-E4B-Vision loaded successfully!")

# %%
import sys
import os
import contextlib

# Suppress all C/C++/Python low-level file descriptor prints during imports
@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

# Completely silence unsloth/transformers startup output and progress bars
os.environ["UNSLOTH_DISABLE_LOGGING"] = "1"
os.environ["TRANSVERSE_NO_PROGRESS_BARS"] = "1"
os.environ["TQDM_DISABLE"] = "1"

with suppress_all_output():
    import torch
    import numpy as np

    # Globally enforce weights_only=False for PyTorch 2.6+ checkpoint loading
    original_torch_load = torch.load
    def patched_torch_load(*args, **kwargs):
        kwargs["weights_only"] = False
        return original_torch_load(*args, **kwargs)
    torch.load = patched_torch_load

    from huggingface_hub import hf_hub_download
    from PIL import Image
    from unsloth import FastVisionModel

MODEL_ID = "frankmorales2020/topo-gemma-4-e4b-vision-13tasks"

with suppress_all_output():
    ckpt_path = hf_hub_download(repo_id=MODEL_ID, filename="pytorch_model.bin")
    checkpoint = torch.load(ckpt_path, map_location="cpu")
    BASE_MODEL = checkpoint.get("base_model", "frankmorales2020/gemma-4-e4b-unesco-optimized")

    model, tokenizer = FastVisionModel.from_pretrained(
        model_name=BASE_MODEL,
        load_in_4bit=True,
        dtype=torch.bfloat16,
    )
    FastVisionModel.for_inference(model)

# 1. Load test image

# 1.1. Download image using wget and load it
from PIL import Image
image_url = "https://picsum.photos/300/300"
image_filename = "test_image.jpg"
os.system(f"wget -q -O {image_filename} {image_url}")

image = Image.open("test_image.jpg").convert("RGB")

# 2. Define all 13 tasks
tasks = [
    ("Task A", "Animal vs Vehicle", "Does this image depict an animal or a vehicle?"),
    ("Task B", "Natural vs Man-Made", "Is this subject natural or man-made?"),
    ("Task C", "Living vs Non-Living", "Is the primary subject living or non-living?"),
    ("Task D", "Large vs Small", "Is the subject large or small in scale?"),
    ("Task E", "Ground vs Air/Water", "Does this subject belong to ground or air/water?"),
    ("Task F", "Domestic vs Wild", "Is this subject domestic or wild?"),
    ("Task G", "Mammal vs Non-Mammal", "Is this subject a mammal or non-mammal?"),
    ("Task H", "Flying vs Non-Flying", "Is this subject flying or non-flying?"),
    ("Task I", "Fast vs Slow", "Is this subject characterized as fast or slow?"),
    ("Task J", "Urban vs Rural", "Does this setting represent an urban or rural environment?"),
    ("Task K", "Predator vs Prey", "Is this subject a predator or prey?"),
    ("Task L", "Nocturnal vs Diurnal", "Is this subject nocturnal or diurnal?"),
    ("Task M", "Domesticated vs Wild Animals", "Is this animal domesticated or wild?")
]

print("\n" + "="*80)
print("🚀 EVALUATING ALL 13 TOPO-2026 TASKS")
print("="*80)

for task_id, task_name, prompt in tasks:
    messages = [
        {
            "role": "user",
            "content": [
                {"type": "image"},
                {"type": "text", "text": f"{task_id} ({task_name}): {prompt}"}
            ]
        }
    ]
    input_text = tokenizer.apply_chat_template(messages, add_generation_prompt=True)

    inputs = tokenizer(
        image,
        input_text,
        add_special_tokens=False,
        return_tensors="pt",
    ).to("cuda")

    with torch.inference_mode():
        output_tokens = model.generate(
            **inputs,
            max_new_tokens=24,
            do_sample=False,
            use_cache=True,
        )

    response = tokenizer.decode(output_tokens[0], skip_special_tokens=True)
    answer = response.split("model")[-1].strip() if "model" in response else response
    print(f"[{task_id}] {task_name:<30} ➔ {answer}")

print("="*80)
print("🎉 EVALUATION COMPLETE!")
print("="*80)

# %% [markdown]
# ## CASE0

# %%
from IPython.display import display, Image as IPImage

# --- In your Orchestrator or execution script ---
IMAGE_FILE = "/content/Screenshot 2026-08-22 at 3.20.05 PM.png"

print("="*80)
print("🖼️ TARGET EVALUATION IMAGE:")
print("="*80)
display(IPImage(filename=IMAGE_FILE, width=400)) # Renders the image directly in the output log
# Out:
# ================================================================================
# 🖼️ TARGET EVALUATION IMAGE:
# ================================================================================

# %%
import sys
import os
import json
import csv
import contextlib

# Suppress low-level output during imports
@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

os.environ["UNSLOTH_DISABLE_LOGGING"] = "1"
os.environ["TRANSVERSE_NO_PROGRESS_BARS"] = "1"
os.environ["TQDM_DISABLE"] = "1"

with suppress_all_output():
    import torch
    import numpy as np

    original_torch_load = torch.load
    def patched_torch_load(*args, **kwargs):
        kwargs["weights_only"] = False
        return original_torch_load(*args, **kwargs)
    torch.load = patched_torch_load

    from huggingface_hub import hf_hub_download
    from PIL import Image
    from unsloth import FastVisionModel

MODEL_ID = "frankmorales2020/topo-gemma-4-e4b-vision-13tasks"

# --- AGENT 1: MODEL LOADER & INFERENCE AGENT ---
class VisionInferenceAgent:
    def __init__(self, model_id):
        self.model_id = model_id
        self.model = None
        self.tokenizer = None
        self._initialize_model()

    def _initialize_model(self):
        with suppress_all_output():
            ckpt_path = hf_hub_download(repo_id=self.model_id, filename="pytorch_model.bin")
            checkpoint = torch.load(ckpt_path, map_location="cpu")
            base_model = checkpoint.get("base_model", "frankmorales2020/gemma-4-e4b-unesco-optimized")

            self.model, self.tokenizer = FastVisionModel.from_pretrained(
                model_name=base_model,
                load_in_4bit=True,
                dtype=torch.bfloat16,
            )
            FastVisionModel.for_inference(self.model)

    def evaluate_task(self, image, task_id, task_name, prompt):
        messages = [
            {
                "role": "user",
                "content": [
                    {"type": "image"},
                    {"type": "text", "text": f"{task_id} ({task_name}): {prompt} Please provide a concise answer followed by a detailed explanation."}
                ]
            }
        ]
        input_text = self.tokenizer.apply_chat_template(messages, add_generation_prompt=True)

        inputs = self.tokenizer(
            image,
            input_text,
            add_special_tokens=False,
            return_tensors="pt",
        ).to("cuda")

        with torch.inference_mode():
            output_tokens = self.model.generate(
                **inputs,
                max_new_tokens=500,  # Increased token limit to 500 for rich, full-length reasoning
                do_sample=False,
                use_cache=True,
            )

        response = self.tokenizer.decode(output_tokens[0], skip_special_tokens=True)
        answer = response.split("model")[-1].strip() if "model" in response else response
        return answer

# --- AGENT 2: VALIDATION & CRITIC AGENT ---
class ValidationAgent:
    def analyze_consistency(self, evaluation_log):
        print("\n🔍 [Validator Agent] Running cross-task consistency checks...")
        flags = []

        animal_mentioned = False
        for item in evaluation_log:
            if item["id"] in ["Task A", "Task G", "Task M"]:
                text_lower = item["result"].lower()
                if "animal" in text_lower and "no animal" not in text_lower:
                    animal_mentioned = True

        for item in evaluation_log:
            if item["id"] == "Task K" and animal_mentioned:
                flags.append("Predator/Prey evaluated while potential animals detected.")

        if not flags:
            flags.append("All logical constraints and cross-task boundaries passed cleanly.")

        return flags

# --- AGENT 3: SYNTHESIZER & EXPORT AGENT ---
class SynthesisAgent:
    def __init__(self):
        self.evaluation_log = []
        self.validator = ValidationAgent()

    def record_result(self, task_id, task_name, raw_answer):
        cleaned_answer = raw_answer.replace("\n", " ").strip()
        self.evaluation_log.append({
            "id": task_id,
            "name": task_name,
            "result": cleaned_answer
        })

    def export_results(self, json_path="evaluation_results.json", csv_path="evaluation_results.csv"):
        with open(json_path, "w", encoding="utf-8") as f:
            json.dump(self.evaluation_log, f, indent=4, ensure_ascii=False)

        with open(csv_path, "w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(["Task ID", "Task Name", "Evaluation Summary"])
            for item in self.evaluation_log:
                writer.writerow([item["id"], item["name"], item["result"]])

        print(f"💾 [Synthesizer Agent] Successfully exported reports to {json_path} and {csv_path}")

    def generate_report(self):
        validation_flags = self.validator.analyze_consistency(self.evaluation_log)

        print("\n" + "="*80)
        print("🏛️ MULTI-AGENT SYNTHESIS & EVALUATION REPORT")
        print("="*80)

        print(f"{'ID':<8} | {'Task Name':<30} | {'Evaluation Summary'}")
        print("-" * 80)
        for item in self.evaluation_log:
            short_res = (item['result'][:47] + '...') if len(item['result']) > 50 else item['result']
            print(f"{item['id']:<8} | {item['name']:<30} | {short_res}")

        print("="*80)
        print("🛡️ VALIDATION & CRITIC LOG:")
        print("="*80)
        for flag in validation_flags:
            print(f" • {flag}")

        print("="*80)
        print("📖 FULL UNTRUNCATED TASK DESCRIPTIONS:")
        print("="*80)
        for item in self.evaluation_log:
            print(f"\n[{item['id']}] {item['name']}")
            print(f"➔ {item['result']}")

        print("\n" + "="*80)
        print("🎉 ALL AGENTS COMPLETED TASKS & EXPORTS SUCCESSFULLY!")
        print("="*80)

# --- AGENT 4: ORCHESTRATOR AGENT ---
class Orchestrator:
    def __init__(self, model_id):
        print("🚀 [Orchestrator] Initializing multi-agent pipeline...")
        self.inference_agent = VisionInferenceAgent(model_id)
        self.synthesis_agent = SynthesisAgent()
        self.image = None

    def load_local_image(self, image_path):
        print(f"📥 [Orchestrator] Loading local image from {image_path}...")
        self.image = Image.open(image_path).convert("RGB")

    def run_pipeline(self, tasks, image_path):
        self.load_local_image(image_path)

        print(f"⚙️ [Orchestrator] Delegating {len(tasks)} tasks to VisionInferenceAgent...")
        for task_id, task_name, prompt in tasks:
            answer = self.inference_agent.evaluate_task(self.image, task_id, task_name, prompt)
            self.synthesis_agent.record_result(task_id, task_name, answer)

        self.synthesis_agent.export_results()
        self.synthesis_agent.generate_report()

# --- EXECUTION ---
if __name__ == "__main__":
    tasks = [
        ("Task A", "Animal vs Vehicle", "Does this image depict an animal or a vehicle?"),
        ("Task B", "Natural vs Man-Made", "Is this subject natural or man-made?"),
        ("Task C", "Living vs Non-Living", "Is the primary subject living or non-living?"),
        ("Task D", "Large vs Small", "Is the subject large or small in scale?"),
        ("Task E", "Ground vs Air/Water", "Does this subject belong to ground or air/water?"),
        ("Task F", "Domestic vs Wild", "Is this subject domestic or wild?"),
        ("Task G", "Mammal vs Non-Mammal", "Is this subject a mammal or non-mammal?"),
        ("Task H", "Flying vs Non-Flying", "Is this subject flying or non-flying?"),
        ("Task I", "Fast vs Slow", "Is this subject characterized as fast or slow?"),
        ("Task J", "Urban vs Rural", "Does this setting represent an urban or rural environment?"),
        ("Task K", "Predator vs Prey", "Is this subject a predator or prey?"),
        ("Task L", "Nocturnal vs Diurnal", "Is this subject nocturnal or diurnal?"),
        ("Task M", "Domesticated vs Wild Animals", "Is this animal domesticated or wild?")
    ]

    IMAGE_FILE = "/content/Screenshot 2026-08-22 at 3.20.05 PM.png"

    pipeline = Orchestrator(MODEL_ID)
    pipeline.run_pipeline(tasks, IMAGE_FILE)
# Out:
# 🚀 [Orchestrator] Initializing multi-agent pipeline...
# Loading weights:   0%|          | 0/2130 [00:00<?, ?it/s]
# 📥 [Orchestrator] Loading local image from /content/Screenshot 2026-08-22 at 3.20.05 PM.png...
# ⚙️ [Orchestrator] Delegating 13 tasks to VisionInferenceAgent...
# 💾 [Synthesizer Agent] Successfully exported reports to evaluation_results.json and evaluation_results.csv
#
# 🔍 [Validator Agent] Running cross-task consistency checks...
#
# ================================================================================
# 🏛️ MULTI-AGENT SYNTHESIS & EVALUATION REPORT
# ================================================================================
# ID       | Task Name                      | Evaluation Summary
# --------------------------------------------------------------------------------
# Task A   | Animal vs Vehicle              | **Answer:** Neither.  **Explanation:** The imag...
# Task B   | Natural vs Man-Made            | **Answer:** Man-made  **Explanation:**  The sub...
# Task C   | Living vs Non-Living           | **Answer:** Non-living  **Explanation:**  The p...
# Task D   | Large vs Small                 | **Concise Answer:** Large  **Detailed Explanati...
# Task E   | Ground vs Air/Water            | **Ground**  **Explanation:**  The image depicts...
# Task F   | Domestic vs Wild               | **Domestic**  **Explanation:**  The image depic...
# Task G   | Mammal vs Non-Mammal           | **Answer:** Non-mammal  **Explanation:**  The i...
# Task H   | Flying vs Non-Flying           | **Non-Flying**  **Explanation:**  The image dep...
# Task I   | Fast vs Slow                   | **Fast**  **Explanation:**  The image depicts a...
# Task J   | Urban vs Rural                 | **Answer:** Urban  **Explanation:**  The settin...
# Task K   | Predator vs Prey               | **Answer:** Neither.  **Explanation:** The subj...
# Task L   | Nocturnal vs Diurnal           | **Diurnal**  **Explanation:**  The image depict...
# Task M   | Domesticated vs Wild Animals   | There are **no animals** visible in this image....
# ================================================================================
# 🛡️ VALIDATION & CRITIC LOG:
# ================================================================================
#  • All logical constraints and cross-task boundaries passed cleanly.
# ================================================================================
# 📖 FULL UNTRUNCATED TASK DESCRIPTIONS:
# ================================================================================
#
# [Task A] Animal vs Vehicle
# ➔ **Answer:** Neither.  **Explanation:** The image depicts the interior of a cafe or restaurant, featuring a large wooden table, two cups of coffee, and a smartphone. There are no animals or vehicles visible in the frame.
#
# [Task B] Natural vs Man-Made
# ➔ **Answer:** Man-made  **Explanation:**  The subject in the image is a collection of objects within an indoor setting, primarily featuring a large wooden table, cups of coffee, and a smartphone. All of these items—the furniture (table), the manufactured goods (cups, phone), and the interior architecture (walls, windows)—are products of human design, construction, and manufacturing. While the wood itself originates from a natural source (trees), the *table* as presented is a processed, constructed, and man-made object.
#
# [Task C] Living vs Non-Living
# ➔ **Answer:** Non-living  **Explanation:**  The primary subject in the image is the **wooden table**. A table is an inanimate object; it does not possess the biological characteristics of life (such as metabolism, growth, reproduction, or responsiveness to stimuli in a biological sense). While there are living elements present in the background (people, plants if any were visible), the focus and the most prominent object in the foreground are the wooden surfaces and the objects resting on them (cups, phone), all of which are non-living.
#
# [Task D] Large vs Small
# ➔ **Concise Answer:** Large  **Detailed Explanation:** The primary subject in the foreground is the large, rustic wooden table. This table dominates the lower half of the image, occupying a significant portion of the frame and establishing a large scale within the composition. While there are smaller elements on the table (coffee cups, phone), the overall scale of the main surface area presented is large.
#
# [Task E] Ground vs Air/Water
# ➔ **Ground**  **Explanation:**  The image depicts an interior scene of a cafe or restaurant. The primary elements visible—the wooden table, the cups of coffee, and the interior architecture—are all firmly situated on the ground plane. While there is a view through a window to the outside (which includes the air/sky), the focus and the main subject matter of the photograph are the objects resting on the solid, horizontal surface of the table, which belongs to the ground domain.
#
# [Task F] Domestic vs Wild
# ➔ **Domestic**  **Explanation:**  The image depicts an interior scene of a cafe or restaurant. This setting is entirely controlled, built, and maintained by humans for social and commercial purposes. The elements present—the wooden table, the cups of coffee, the interior decor, and the visible storefront/window—are all examples of human-made, domesticated environments, contrasting sharply with a "wild" setting (like a forest, desert, or untouched wilderness).
#
# [Task G] Mammal vs Non-Mammal
# ➔ **Answer:** Non-mammal  **Explanation:**  The image provided is of an interior scene in a cafe, featuring a large wooden table, coffee cups, and people in the background. There are **no visible subjects** in the image that belong to the class Mammalia (mammals).  Since the prompt asks to classify "this subject," and the only discernible elements are inanimate objects (table, cups) or distant, indistinct human figures (which are mammals), the question is unanswerable based on a clear, identifiable biological subject. However, if the question is interpreted as asking about the *primary focus* or the *most prominent elements*, they are inanimate. If the question is strictly about identifying a biological subject *within* the frame, the human figures are mammals.  Given the ambiguity, and assuming the question intends to test biological knowledge based on a visible subject, the lack of a clear, singular biological subject makes a definitive classification impossible. If forced to choose based on the *potential* subjects (the people), they are mammals. But since the image is primarily an **environmental/still life shot**, it contains no definitive biological subject to classify as mammal or non-mammal.  **Conclusion based on the visual evidence:** The image does not contain a clear, identifiable biological subject to classify.
#
# [Task H] Flying vs Non-Flying
# ➔ **Non-Flying**  **Explanation:**  The image depicts the interior of a cafe or restaurant. There are people seated at tables, and the setting is clearly an indoor commercial space. There is no visual evidence, context, or indication that the subject (the scene itself) is related to aviation, flight, or airborne travel. Therefore, it is a non-flying subject.
#
# [Task I] Fast vs Slow
# ➔ **Fast**  **Explanation:**  The image depicts a scene in a cafe or restaurant, which is inherently a setting associated with a relatively **fast-paced** or transient experience, even if the act of drinking coffee is slow.  Here is a breakdown of why "fast" is the more appropriate characterization in this context:  1. **Commercial/Service Environment:** Cafes and restaurants are commercial spaces designed for quick turnover of customers and service delivery. While patrons might linger, the *environment itself* operates on a schedule of service (ordering, preparation, consumption, departure). 2. **Visual Cues of Activity:** The background shows people seated and interacting, suggesting ongoing activity and movement (even if subtle). The bright, open nature of the space suggests a public, active setting. 3. **Contrast with "Slow":** "Slow" might imply a deeply contemplative, static, or extremely leisurely setting (like a remote countryside retreat or a very quiet library). This cafe setting, with its wooden tables and visible activity, suggests a more dynamic, everyday pace of life.  While the *act* of sipping coffee is slow, the *subject* (the cafe experience) is characterized by the rhythm of modern, public, service-oriented life, which leans toward the "fast" category when compared to truly slow subjects.
#
# [Task J] Urban vs Rural
# ➔ **Answer:** Urban  **Explanation:**  The setting strongly suggests an urban environment for several reasons:  1. **Large Glass Windows/Storefront:** The presence of large, expansive windows looking out onto a street scene is characteristic of commercial or high-density urban areas. 2. **Visible Activity Outside:** Through the windows, there are figures (people) visible, suggesting foot traffic and commercial activity typical of a city street. 3. **Interior Design:** The style of the cafe—modern, minimalist, and featuring large wooden communal tables—is very common in contemporary urban cafes and bistros. 4. **Lack of Natural Landscape:** There is no visible sign of extensive natural landscape (fields, forests, etc.), which would be the defining feature of a rural setting.  The overall ambiance points to a bustling, developed, and commercialized city location.
#
# [Task K] Predator vs Prey
# ➔ **Answer:** Neither.  **Explanation:** The subject in the image is an **interior scene of a cafe or restaurant**. It is a static, inanimate environment and does not participate in a predator-prey dynamic. The elements present (tables, chairs, coffee cups, people) are part of a human-made setting and do not represent biological entities engaged in a hunt or being hunted.
#
# [Task L] Nocturnal vs Diurnal
# ➔ **Diurnal**  **Explanation:**  The image depicts an interior scene of a cafe or restaurant during what appears to be daytime. The large windows show bright, natural light flooding the space, and the general ambiance suggests normal daytime business hours. Nocturnal subjects are typically associated with activities or behaviors occurring primarily at night.
#
# [Task M] Domesticated vs Wild Animals
# ➔ There are **no animals** visible in this image.  **Detailed Explanation:** The image depicts the interior of a cafe or restaurant. It features a large, rustic wooden table, two cups of coffee, and a smartphone. There are people visible in the background through a large window, but they are human, not animals. Therefore, the question regarding domesticated or wild animals cannot be answered based on the provided visual information.
#
# ================================================================================
# 🎉 ALL AGENTS COMPLETED TASKS & EXPORTS SUCCESSFULLY!
# ================================================================================

# %% [markdown]
# ## CASE1

# %%
from IPython.display import display, Image as IPImage

# --- In your Orchestrator or execution script ---
IMAGE_FILE = "/content/Screenshot 2026-08-22 at 5.02.31 PM.png"

print("="*80)
print("🖼️ TARGET EVALUATION IMAGE:")
print("="*80)
display(IPImage(filename=IMAGE_FILE, width=400)) # Renders the image directly in the output log
# Out:
# ================================================================================
# 🖼️ TARGET EVALUATION IMAGE:
# ================================================================================

# %%
import sys
import os
import json
import csv
import contextlib

# Suppress low-level output during imports
@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

os.environ["UNSLOTH_DISABLE_LOGGING"] = "1"
os.environ["TRANSVERSE_NO_PROGRESS_BARS"] = "1"
os.environ["TQDM_DISABLE"] = "1"

with suppress_all_output():
    import torch
    import numpy as np

    original_torch_load = torch.load
    def patched_torch_load(*args, **kwargs):
        kwargs["weights_only"] = False
        return original_torch_load(*args, **kwargs)
    torch.load = patched_torch_load

    from huggingface_hub import hf_hub_download
    from PIL import Image
    from unsloth import FastVisionModel

MODEL_ID = "frankmorales2020/topo-gemma-4-e4b-vision-13tasks"

# --- AGENT 1: MODEL LOADER & INFERENCE AGENT ---
class VisionInferenceAgent:
    def __init__(self, model_id):
        self.model_id = model_id
        self.model = None
        self.tokenizer = None
        self._initialize_model()

    def _initialize_model(self):
        with suppress_all_output():
            ckpt_path = hf_hub_download(repo_id=self.model_id, filename="pytorch_model.bin")
            checkpoint = torch.load(ckpt_path, map_location="cpu")
            base_model = checkpoint.get("base_model", "frankmorales2020/gemma-4-e4b-unesco-optimized")

            self.model, self.tokenizer = FastVisionModel.from_pretrained(
                model_name=base_model,
                load_in_4bit=True,
                dtype=torch.bfloat16,
            )
            FastVisionModel.for_inference(self.model)

    def evaluate_task(self, image, task_id, task_name, prompt):
        messages = [
            {
                "role": "user",
                "content": [
                    {"type": "image"},
                    {"type": "text", "text": f"{task_id} ({task_name}): {prompt} Please provide a concise answer followed by a detailed explanation."}
                ]
            }
        ]
        input_text = self.tokenizer.apply_chat_template(messages, add_generation_prompt=True)

        inputs = self.tokenizer(
            image,
            input_text,
            add_special_tokens=False,
            return_tensors="pt",
        ).to("cuda")

        with torch.inference_mode():
            output_tokens = self.model.generate(
                **inputs,
                max_new_tokens=500,  # Increased token limit to 500 for rich, full-length reasoning
                do_sample=False,
                use_cache=True,
            )

        response = self.tokenizer.decode(output_tokens[0], skip_special_tokens=True)
        answer = response.split("model")[-1].strip() if "model" in response else response
        return answer

# --- AGENT 2: VALIDATION & CRITIC AGENT ---
class ValidationAgent:
    def analyze_consistency(self, evaluation_log):
        print("\n🔍 [Validator Agent] Running cross-task consistency checks...")
        flags = []

        animal_mentioned = False
        for item in evaluation_log:
            if item["id"] in ["Task A", "Task G", "Task M"]:
                text_lower = item["result"].lower()
                if "animal" in text_lower and "no animal" not in text_lower:
                    animal_mentioned = True

        for item in evaluation_log:
            if item["id"] == "Task K" and animal_mentioned:
                flags.append("Predator/Prey evaluated while potential animals detected.")

        if not flags:
            flags.append("All logical constraints and cross-task boundaries passed cleanly.")

        return flags

# --- AGENT 3: SYNTHESIZER & EXPORT AGENT ---
class SynthesisAgent:
    def __init__(self):
        self.evaluation_log = []
        self.validator = ValidationAgent()

    def record_result(self, task_id, task_name, raw_answer):
        cleaned_answer = raw_answer.replace("\n", " ").strip()
        self.evaluation_log.append({
            "id": task_id,
            "name": task_name,
            "result": cleaned_answer
        })

    def export_results(self, json_path="evaluation_results.json", csv_path="evaluation_results.csv"):
        with open(json_path, "w", encoding="utf-8") as f:
            json.dump(self.evaluation_log, f, indent=4, ensure_ascii=False)

        with open(csv_path, "w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(["Task ID", "Task Name", "Evaluation Summary"])
            for item in self.evaluation_log:
                writer.writerow([item["id"], item["name"], item["result"]])

        print(f"💾 [Synthesizer Agent] Successfully exported reports to {json_path} and {csv_path}")

    def generate_report(self):
        validation_flags = self.validator.analyze_consistency(self.evaluation_log)

        print("\n" + "="*80)
        print("🏛️ MULTI-AGENT SYNTHESIS & EVALUATION REPORT")
        print("="*80)

        print(f"{'ID':<8} | {'Task Name':<30} | {'Evaluation Summary'}")
        print("-" * 80)
        for item in self.evaluation_log:
            short_res = (item['result'][:47] + '...') if len(item['result']) > 50 else item['result']
            print(f"{item['id']:<8} | {item['name']:<30} | {short_res}")

        print("="*80)
        print("🛡️ VALIDATION & CRITIC LOG:")
        print("="*80)
        for flag in validation_flags:
            print(f" • {flag}")

        print("="*80)
        print("📖 FULL UNTRUNCATED TASK DESCRIPTIONS:")
        print("="*80)
        for item in self.evaluation_log:
            print(f"\n[{item['id']}] {item['name']}")
            print(f"➔ {item['result']}")

        print("\n" + "="*80)
        print("🎉 ALL AGENTS COMPLETED TASKS & EXPORTS SUCCESSFULLY!")
        print("="*80)

# --- AGENT 4: ORCHESTRATOR AGENT ---
class Orchestrator:
    def __init__(self, model_id):
        print("🚀 [Orchestrator] Initializing multi-agent pipeline...")
        self.inference_agent = VisionInferenceAgent(model_id)
        self.synthesis_agent = SynthesisAgent()
        self.image = None

    def load_local_image(self, image_path):
        print(f"📥 [Orchestrator] Loading local image from {image_path}...")
        self.image = Image.open(image_path).convert("RGB")

    def run_pipeline(self, tasks, image_path):
        self.load_local_image(image_path)

        print(f"⚙️ [Orchestrator] Delegating {len(tasks)} tasks to VisionInferenceAgent...")
        for task_id, task_name, prompt in tasks:
            answer = self.inference_agent.evaluate_task(self.image, task_id, task_name, prompt)
            self.synthesis_agent.record_result(task_id, task_name, answer)

        self.synthesis_agent.export_results()
        self.synthesis_agent.generate_report()

# --- EXECUTION ---
if __name__ == "__main__":
    tasks = [
        ("Task A", "Animal vs Vehicle", "Does this image depict an animal or a vehicle?"),
        ("Task B", "Natural vs Man-Made", "Is this subject natural or man-made?"),
        ("Task C", "Living vs Non-Living", "Is the primary subject living or non-living?"),
        ("Task D", "Large vs Small", "Is the subject large or small in scale?"),
        ("Task E", "Ground vs Air/Water", "Does this subject belong to ground or air/water?"),
        ("Task F", "Domestic vs Wild", "Is this subject domestic or wild?"),
        ("Task G", "Mammal vs Non-Mammal", "Is this subject a mammal or non-mammal?"),
        ("Task H", "Flying vs Non-Flying", "Is this subject flying or non-flying?"),
        ("Task I", "Fast vs Slow", "Is this subject characterized as fast or slow?"),
        ("Task J", "Urban vs Rural", "Does this setting represent an urban or rural environment?"),
        ("Task K", "Predator vs Prey", "Is this subject a predator or prey?"),
        ("Task L", "Nocturnal vs Diurnal", "Is this subject nocturnal or diurnal?"),
        ("Task M", "Domesticated vs Wild Animals", "Is this animal domesticated or wild?")
    ]

    IMAGE_FILE = "/content/Screenshot 2026-08-22 at 5.02.31 PM.png"

    pipeline = Orchestrator(MODEL_ID)
    pipeline.run_pipeline(tasks, IMAGE_FILE)
# Out:
# 🚀 [Orchestrator] Initializing multi-agent pipeline...
# Loading weights:   0%|          | 0/2130 [00:00<?, ?it/s]
# 📥 [Orchestrator] Loading local image from /content/Screenshot 2026-08-22 at 5.02.31 PM.png...
# ⚙️ [Orchestrator] Delegating 13 tasks to VisionInferenceAgent...
# 💾 [Synthesizer Agent] Successfully exported reports to evaluation_results.json and evaluation_results.csv
#
# 🔍 [Validator Agent] Running cross-task consistency checks...
#
# ================================================================================
# 🏛️ MULTI-AGENT SYNTHESIS & EVALUATION REPORT
# ================================================================================
# ID       | Task Name                      | Evaluation Summary
# --------------------------------------------------------------------------------
# Task A   | Animal vs Vehicle              | **Answer:** Vehicle  **Explanation:** The image...
# Task B   | Natural vs Man-Made            | **Answer:** Man-made  **Explanation:**  The ima...
# Task C   | Living vs Non-Living           | **Answer:** Non-living  **Explanation:**  The p...
# Task D   | Large vs Small                 | **Concise Answer:** Large  **Detailed Explanati...
# Task E   | Ground vs Air/Water            | **Answer:** Air/Water  **Explanation:**  The su...
# Task F   | Domestic vs Wild               | **Concise Answer:** Domestic  **Detailed Explan...
# Task G   | Mammal vs Non-Mammal           | **Answer:** Non-mammal  **Explanation:**  The i...
# Task H   | Flying vs Non-Flying           | **Answer:** Flying  **Explanation:**  The image...
# Task I   | Fast vs Slow                   | **Answer:** Slow  **Explanation:**  The subject...
# Task J   | Urban vs Rural                 | **Answer:** Urban  **Explanation:**  This setti...
# Task K   | Predator vs Prey               | **Answer:** Neither.  **Explanation:**  The sub...
# Task L   | Nocturnal vs Diurnal           | **Answer:** Diurnal  **Explanation:**  The imag...
# Task M   | Domesticated vs Wild Animals   | Based on the image provided, there is **no anim...
# ================================================================================
# 🛡️ VALIDATION & CRITIC LOG:
# ================================================================================
#  • Predator/Prey evaluated while potential animals detected.
# ================================================================================
# 📖 FULL UNTRUNCATED TASK DESCRIPTIONS:
# ================================================================================
#
# [Task A] Animal vs Vehicle
# ➔ **Answer:** Vehicle  **Explanation:** The image clearly depicts a large suspension bridge structure, which is a piece of civil engineering infrastructure. While the bridge itself is not a vehicle, the context of the image—showing a roadway deck supported by towers and cables—is characteristic of a transportation route designed for vehicles (cars, trucks, etc.) to travel upon. There are no discernible animals in the frame.
#
# [Task B] Natural vs Man-Made
# ➔ **Answer:** Man-made  **Explanation:**  The image clearly depicts a **suspension bridge**. A bridge is a large-scale structure built by humans to span a physical obstacle (in this case, likely a body of water). Key features visible in the image—the towering support pylon, the suspension cables, and the roadway deck—are all engineered and constructed elements, making the entire subject definitively man-made.
#
# [Task C] Living vs Non-Living
# ➔ **Answer:** Non-living  **Explanation:**  The primary subject in the image is a **suspension bridge**. A bridge is a large, man-made structure constructed from materials like steel and concrete. It does not possess the biological characteristics of life, such as metabolism, reproduction, growth (in the biological sense), or cellular structure. Therefore, it is classified as a non-living object.
#
# [Task D] Large vs Small
# ➔ **Concise Answer:** Large  **Detailed Explanation:**  The subject, which is a large suspension bridge, is inherently massive in scale. The photograph captures a significant portion of the bridge's structure—the main tower and the supporting cables stretching out over a vast expanse of water. The sheer size of the tower relative to the frame, and the implied scale of the bridge spanning a large body of water, clearly indicates a large-scale subject.
#
# [Task E] Ground vs Air/Water
# ➔ **Answer:** Air/Water  **Explanation:**  The subject of the image is a large suspension bridge spanning over a body of water (likely the sea or a large bay). While the bridge structure itself is a man-made object built on the ground, the *context* and the *primary visual focus* are the bridge structure interacting with and spanning the **water**.  In the context of "Ground vs Air/Water," this image is categorized as **Air/Water** because:  1. **Dominant Element:** The vast expanse of water occupies the majority of the frame and is the element the bridge is crossing. 2. **Environmental Setting:** The scene is defined by the interface between the structure and the large body of water, placing it firmly in a maritime or coastal environment, which falls under the "Water" category.  Although the bridge has foundations on the ground, the perspective and the overwhelming presence of the water make "Air/Water" the most appropriate classification for this specific photograph.
#
# [Task F] Domestic vs Wild
# ➔ **Concise Answer:** Domestic  **Detailed Explanation:**  The subject in the image is a large suspension bridge. A bridge is a piece of civil engineering infrastructure, which is a man-made structure. Man-made structures are classified as **domestic** (or artificial/human-made) rather than wild, which refers to natural environments or organisms.
#
# [Task G] Mammal vs Non-Mammal
# ➔ **Answer:** Non-mammal  **Explanation:**  The image provided is a photograph of a **suspension bridge** over a body of water. A bridge is a piece of civil engineering infrastructure, not a living organism. Therefore, it does not belong to the biological classification of a mammal (which are warm-blooded vertebrates characterized by mammary glands) or a non-mammal (which is a broad category including reptiles, birds, fish, amphibians, and invertebrates).  Since the subject is an inanimate object, it is classified as **non-biological** in the context of the mammal vs. non-mammal dichotomy.
#
# [Task H] Flying vs Non-Flying
# ➔ **Answer:** Flying  **Explanation:**  The image clearly depicts a **suspension bridge** spanning over a large body of water (likely the sea or a large river). The structure itself is a massive piece of civil engineering designed to allow traffic (vehicles, etc.) to move *over* the water, which is a form of elevated, spanning structure.  While the *photographer* might be flying (e.g., in a drone or aircraft), the *subject* of the photograph—the bridge—is a **flying structure** in the sense that it is elevated high above the ground/water surface, supported by cables and towers, allowing passage across a gap. In the context of structural classification, a suspension bridge is a classic example of a structure designed to "fly" or span a distance.
#
# [Task I] Fast vs Slow
# ➔ **Answer:** Slow  **Explanation:**  The subject in the image is a large suspension bridge spanning a body of water. Bridges, by their nature, are fixed, massive, and static structures designed to facilitate movement across a span. While the traffic moving across the bridge is dynamic, the bridge itself is a slow-moving, enduring element of the landscape.  In the context of "fast vs. slow," the bridge represents **slowness** because:  1. **Inertia and Scale:** It is a massive, heavy structure with immense inertia, moving or changing state very slowly (if at all, barring seismic events). 2. **Function:** Its primary function is to provide a stable, relatively unchanging pathway for transport, contrasting with the rapid movement of vehicles or the swiftness of water currents.  Therefore, when characterizing the *subject* (the bridge), "slow" is the most appropriate descriptor.
#
# [Task J] Urban vs Rural
# ➔ **Answer:** Urban  **Explanation:**  This setting represents an urban environment because the structure shown is a large suspension bridge, which is a piece of major infrastructure typically built to span significant bodies of water within or connecting major metropolitan areas. While the immediate surroundings visible are water, the presence of such a massive, engineered structure strongly implies proximity to or connection with a densely populated, developed area (a city). Rural environments are characterized by open land, agriculture, and a lack of such large-scale, complex transportation infrastructure.
#
# [Task K] Predator vs Prey
# ➔ **Answer:** Neither.  **Explanation:**  The subject in the image is a **suspension bridge**. It is a piece of civil engineering infrastructure, not a living organism. Therefore, the concepts of "predator" or "prey" do not apply to it in a biological sense.  *   **Predator:** An organism that naturally preys upon other organisms. *   **Prey:** An organism that is hunted and eaten by another organism.  Since the bridge is inanimate, it exists outside the ecological food web.
#
# [Task L] Nocturnal vs Diurnal
# ➔ **Answer:** Diurnal  **Explanation:**  The image depicts a large suspension bridge over a body of water. While the lighting is somewhat muted (suggesting an overcast day or perhaps twilight), the structure itself—a massive piece of civil engineering—is not inherently nocturnal or diurnal in the biological sense.  However, when interpreting the *subject* in the context of typical environmental or photographic classification:  1. **The Bridge (Inanimate Object):** A bridge is a permanent, static structure and does not exhibit diurnal or nocturnal behavior. 2. **The Context (Daylight/Ambient Light):** The photograph was taken during a period of ambient light (daytime or civil twilight).  Since the image captures a scene under natural daylight conditions, the context leans toward **diurnal**. If the image were taken at night with artificial lighting being the primary source of illumination, it might be argued as nocturnal, but based on the visual evidence, it is best classified as diurnal.
#
# [Task M] Domesticated vs Wild Animals
# ➔ Based on the image provided, there is **no animal** visible.  Therefore, I cannot answer whether an animal is domesticated or wild. The image is a photograph of a large suspension bridge over a body of water.
#
# ================================================================================
# 🎉 ALL AGENTS COMPLETED TASKS & EXPORTS SUCCESSFULLY!
# ================================================================================

# %% [markdown]
# ## CASE2

# %%
from IPython.display import display, Image as IPImage

# --- In your Orchestrator or execution script ---
IMAGE_FILE = "/content/Screenshot 2026-08-22 at 5.09.43 PM.png"

print("="*80)
print("🖼️ TARGET EVALUATION IMAGE:")
print("="*80)
display(IPImage(filename=IMAGE_FILE, width=400)) # Renders the image directly in the output log
# Out:
# ================================================================================
# 🖼️ TARGET EVALUATION IMAGE:
# ================================================================================

# %%
import sys
import os
import json
import csv
import contextlib

# Suppress low-level output during imports
@contextlib.contextmanager
def suppress_all_output():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        old_stderr = sys.stderr
        sys.stdout = devnull
        sys.stderr = devnull
        try:
            yield
        finally:
            sys.stdout = old_stdout
            sys.stderr = old_stderr

os.environ["UNSLOTH_DISABLE_LOGGING"] = "1"
os.environ["TRANSVERSE_NO_PROGRESS_BARS"] = "1"
os.environ["TQDM_DISABLE"] = "1"

with suppress_all_output():
    import torch
    import numpy as np

    original_torch_load = torch.load
    def patched_torch_load(*args, **kwargs):
        kwargs["weights_only"] = False
        return original_torch_load(*args, **kwargs)
    torch.load = patched_torch_load

    from huggingface_hub import hf_hub_download
    from PIL import Image
    from unsloth import FastVisionModel

MODEL_ID = "frankmorales2020/topo-gemma-4-e4b-vision-13tasks"

# --- AGENT 1: MODEL LOADER & INFERENCE AGENT ---
class VisionInferenceAgent:
    def __init__(self, model_id):
        self.model_id = model_id
        self.model = None
        self.tokenizer = None
        self._initialize_model()

    def _initialize_model(self):
        with suppress_all_output():
            ckpt_path = hf_hub_download(repo_id=self.model_id, filename="pytorch_model.bin")
            checkpoint = torch.load(ckpt_path, map_location="cpu")
            base_model = checkpoint.get("base_model", "frankmorales2020/gemma-4-e4b-unesco-optimized")

            self.model, self.tokenizer = FastVisionModel.from_pretrained(
                model_name=base_model,
                load_in_4bit=True,
                dtype=torch.bfloat16,
            )
            FastVisionModel.for_inference(self.model)

    def evaluate_task(self, image, task_id, task_name, prompt):
        messages = [
            {
                "role": "user",
                "content": [
                    {"type": "image"},
                    {"type": "text", "text": f"{task_id} ({task_name}): {prompt} Please provide a concise answer followed by a detailed explanation."}
                ]
            }
        ]
        input_text = self.tokenizer.apply_chat_template(messages, add_generation_prompt=True)

        inputs = self.tokenizer(
            image,
            input_text,
            add_special_tokens=False,
            return_tensors="pt",
        ).to("cuda")

        with torch.inference_mode():
            output_tokens = self.model.generate(
                **inputs,
                max_new_tokens=500,  # Increased token limit to 500 for rich, full-length reasoning
                do_sample=False,
                use_cache=True,
            )

        response = self.tokenizer.decode(output_tokens[0], skip_special_tokens=True)
        answer = response.split("model")[-1].strip() if "model" in response else response
        return answer

# --- AGENT 2: VALIDATION & CRITIC AGENT ---
class ValidationAgent:
    def analyze_consistency(self, evaluation_log):
        print("\n🔍 [Validator Agent] Running cross-task consistency checks...")
        flags = []

        animal_mentioned = False
        for item in evaluation_log:
            if item["id"] in ["Task A", "Task G", "Task M"]:
                text_lower = item["result"].lower()
                if "animal" in text_lower and "no animal" not in text_lower:
                    animal_mentioned = True

        for item in evaluation_log:
            if item["id"] == "Task K" and animal_mentioned:
                flags.append("Predator/Prey evaluated while potential animals detected.")

        if not flags:
            flags.append("All logical constraints and cross-task boundaries passed cleanly.")

        return flags

# --- AGENT 3: SYNTHESIZER & EXPORT AGENT ---
class SynthesisAgent:
    def __init__(self):
        self.evaluation_log = []
        self.validator = ValidationAgent()

    def record_result(self, task_id, task_name, raw_answer):
        cleaned_answer = raw_answer.replace("\n", " ").strip()
        self.evaluation_log.append({
            "id": task_id,
            "name": task_name,
            "result": cleaned_answer
        })

    def export_results(self, json_path="evaluation_results.json", csv_path="evaluation_results.csv"):
        with open(json_path, "w", encoding="utf-8") as f:
            json.dump(self.evaluation_log, f, indent=4, ensure_ascii=False)

        with open(csv_path, "w", newline="", encoding="utf-8") as f:
            writer = csv.writer(f)
            writer.writerow(["Task ID", "Task Name", "Evaluation Summary"])
            for item in self.evaluation_log:
                writer.writerow([item["id"], item["name"], item["result"]])

        print(f"💾 [Synthesizer Agent] Successfully exported reports to {json_path} and {csv_path}")

    def generate_report(self):
        validation_flags = self.validator.analyze_consistency(self.evaluation_log)

        print("\n" + "="*80)
        print("🏛️ MULTI-AGENT SYNTHESIS & EVALUATION REPORT")
        print("="*80)

        print(f"{'ID':<8} | {'Task Name':<30} | {'Evaluation Summary'}")
        print("-" * 80)
        for item in self.evaluation_log:
            short_res = (item['result'][:47] + '...') if len(item['result']) > 50 else item['result']
            print(f"{item['id']:<8} | {item['name']:<30} | {short_res}")

        print("="*80)
        print("🛡️ VALIDATION & CRITIC LOG:")
        print("="*80)
        for flag in validation_flags:
            print(f" • {flag}")

        print("="*80)
        print("📖 FULL UNTRUNCATED TASK DESCRIPTIONS:")
        print("="*80)
        for item in self.evaluation_log:
            print(f"\n[{item['id']}] {item['name']}")
            print(f"➔ {item['result']}")

        print("\n" + "="*80)
        print("🎉 ALL AGENTS COMPLETED TASKS & EXPORTS SUCCESSFULLY!")
        print("="*80)

# --- AGENT 4: ORCHESTRATOR AGENT ---
class Orchestrator:
    def __init__(self, model_id):
        print("🚀 [Orchestrator] Initializing multi-agent pipeline...")
        self.inference_agent = VisionInferenceAgent(model_id)
        self.synthesis_agent = SynthesisAgent()
        self.image = None

    def load_local_image(self, image_path):
        print(f"📥 [Orchestrator] Loading local image from {image_path}...")
        self.image = Image.open(image_path).convert("RGB")

    def run_pipeline(self, tasks, image_path):
        self.load_local_image(image_path)

        print(f"⚙️ [Orchestrator] Delegating {len(tasks)} tasks to VisionInferenceAgent...")
        for task_id, task_name, prompt in tasks:
            answer = self.inference_agent.evaluate_task(self.image, task_id, task_name, prompt)
            self.synthesis_agent.record_result(task_id, task_name, answer)

        self.synthesis_agent.export_results()
        self.synthesis_agent.generate_report()

# --- EXECUTION ---
if __name__ == "__main__":
    tasks = [
        ("Task A", "Animal vs Vehicle", "Does this image depict an animal or a vehicle?"),
        ("Task B", "Natural vs Man-Made", "Is this subject natural or man-made?"),
        ("Task C", "Living vs Non-Living", "Is the primary subject living or non-living?"),
        ("Task D", "Large vs Small", "Is the subject large or small in scale?"),
        ("Task E", "Ground vs Air/Water", "Does this subject belong to ground or air/water?"),
        ("Task F", "Domestic vs Wild", "Is this subject domestic or wild?"),
        ("Task G", "Mammal vs Non-Mammal", "Is this subject a mammal or non-mammal?"),
        ("Task H", "Flying vs Non-Flying", "Is this subject flying or non-flying?"),
        ("Task I", "Fast vs Slow", "Is this subject characterized as fast or slow?"),
        ("Task J", "Urban vs Rural", "Does this setting represent an urban or rural environment?"),
        ("Task K", "Predator vs Prey", "Is this subject a predator or prey?"),
        ("Task L", "Nocturnal vs Diurnal", "Is this subject nocturnal or diurnal?"),
        ("Task M", "Domesticated vs Wild Animals", "Is this animal domesticated or wild?")
    ]

    IMAGE_FILE = "/content/Screenshot 2026-08-22 at 5.09.43 PM.png"

    pipeline = Orchestrator(MODEL_ID)
    pipeline.run_pipeline(tasks, IMAGE_FILE)
# Out:
# 🚀 [Orchestrator] Initializing multi-agent pipeline...
# Loading weights:   0%|          | 0/2130 [00:00<?, ?it/s]
# 📥 [Orchestrator] Loading local image from /content/Screenshot 2026-08-22 at 5.09.43 PM.png...
# ⚙️ [Orchestrator] Delegating 13 tasks to VisionInferenceAgent...
# 💾 [Synthesizer Agent] Successfully exported reports to evaluation_results.json and evaluation_results.csv
#
# 🔍 [Validator Agent] Running cross-task consistency checks...
#
# ================================================================================
# 🏛️ MULTI-AGENT SYNTHESIS & EVALUATION REPORT
# ================================================================================
# ID       | Task Name                      | Evaluation Summary
# --------------------------------------------------------------------------------
# Task A   | Animal vs Vehicle              | **Answer:** Animal  **Explanation:** The image ...
# Task B   | Natural vs Man-Made            | **Answer:** Natural  **Explanation:**  The subj...
# Task C   | Living vs Non-Living           | **Answer:** Living  **Explanation:** The primar...
# Task D   | Large vs Small                 | **Concise Answer:** Large  **Detailed Explanati...
# Task E   | Ground vs Air/Water            | **Ground**  **Explanation:**  The primary subje...
# Task F   | Domestic vs Wild               | **Wild**  **Explanation:** The subject, which i...
# Task G   | Mammal vs Non-Mammal           | **Mammal**  **Explanation:**  The image clearly...
# Task H   | Flying vs Non-Flying           | **Non-flying**  **Explanation:**  The primary s...
# Task I   | Fast vs Slow                   | **Slow**  **Explanation:**  The primary subject...
# Task J   | Urban vs Rural                 | **Answer:** Rural  **Explanation:**  This setti...
# Task K   | Predator vs Prey               | **Prey**  **Explanation:**  The image primarily...
# Task L   | Nocturnal vs Diurnal           | **Diurnal**  **Explanation:**  The subject, ele...
# Task M   | Domesticated vs Wild Animals   | **Wild**  **Explanation:** The animals visible ...
# ================================================================================
# 🛡️ VALIDATION & CRITIC LOG:
# ================================================================================
#  • Predator/Prey evaluated while potential animals detected.
# ================================================================================
# 📖 FULL UNTRUNCATED TASK DESCRIPTIONS:
# ================================================================================
#
# [Task A] Animal vs Vehicle
# ➔ **Answer:** Animal  **Explanation:** The image clearly depicts several large mammals, specifically elephants, which are animals. There are no visible vehicles in the photograph.
#
# [Task B] Natural vs Man-Made
# ➔ **Answer:** Natural  **Explanation:**  The subject depicted in the image is overwhelmingly natural. It features a wildlife scene in an African savanna or bushland environment. The elements present—elephants, various other wild animals (implied or visible), the landscape (grassland, scrub, hills), and the sky (clouds, sunset/sunrise)—are all products of natural processes.  While the photograph itself is a *man-made* artifact (a captured image), the *subject matter* being photographed is entirely natural. There are no visible structures, buildings, or artificial installations that would classify the scene as man-made.
#
# [Task C] Living vs Non-Living
# ➔ **Answer:** Living  **Explanation:** The primary subjects in the image are the elephants, which are biological organisms and therefore living things. While the sky, clouds, and landscape are non-living elements, the presence of the elephants makes the living subjects the most prominent and central focus of the scene.
#
# [Task D] Large vs Small
# ➔ **Concise Answer:** Large  **Detailed Explanation:**  The primary subjects in the image—the elephants—are inherently large animals. Furthermore, the composition emphasizes their scale by placing them in the foreground against the vast backdrop of the savanna landscape, the expansive sky, and the dramatic sunset. The elephants dominate the lower portion of the frame, making them appear substantial and large relative to the surrounding environment and any smaller elements present.
#
# [Task E] Ground vs Air/Water
# ➔ **Ground**  **Explanation:**  The primary subjects in the image—the elephants, the herd animals, and the landscape itself—are all terrestrial. The elephants are clearly walking on the ground, and the environment depicted is a savanna or open grassland. While there is a dramatic sky with clouds and a sunset (an "air" element), the focus and the main action of the scene are entirely situated on the ground plane.
#
# [Task F] Domestic vs Wild
# ➔ **Wild**  **Explanation:** The subject, which includes elephants and other wildlife visible in the scene, is wild. Elephants in this natural, savanna-like environment are wild animals. The image depicts a natural habitat with various wild animals interacting in a landscape setting, not a domesticated farm or controlled environment.
#
# [Task G] Mammal vs Non-Mammal
# ➔ **Mammal**  **Explanation:**  The image clearly depicts several elephants. Elephants are large, terrestrial mammals belonging to the order Proboscidea. Key characteristics that confirm they are mammals include:  1.  **Warm-bloodedness:** Mammals are endothermic, maintaining a constant internal body temperature. 2.  **Mammary Glands:** Female elephants nurse their young with milk produced by mammary glands. 3.  **Hair/Fur:** While elephants have sparse hair, they possess skin structures typical of mammals. 4.  **Reproduction:** They give live birth to young.  Since the primary subjects in the foreground are elephants, the subject matter is definitively mammalian.
#
# [Task H] Flying vs Non-Flying
# ➔ **Non-flying**  **Explanation:**  The primary subjects in the image are elephants, which are terrestrial mammals and are not capable of flight. While there are birds visible in the sky (which are flying), the focus of the scene and the most prominent subjects are the elephants, which are clearly depicted on the ground. Therefore, the main subject matter is non-flying.
#
# [Task I] Fast vs Slow
# ➔ **Slow**  **Explanation:**  The primary subjects in the image are elephants, which are large, heavy, and inherently slow-moving animals. While the image captures a dynamic scene with dramatic lighting and dust, the action depicted—the elephants walking or standing in the savanna—is characteristic of slow, deliberate movement. The overall mood and subject matter emphasize the massive, grounded presence of the wildlife rather than rapid motion.
#
# [Task J] Urban vs Rural
# ➔ **Answer:** Rural  **Explanation:**  This setting clearly represents a **rural** environment. The image depicts a natural landscape characterized by open savanna, scattered trees, and a herd of wild animals (elephants and other wildlife). There are no visible signs of dense human infrastructure such as tall buildings, paved roads, commercial storefronts, or heavy industrial development, which are hallmarks of an urban area. The presence of wildlife in a natural habitat confirms its designation as a rural or wilderness setting.
#
# [Task K] Predator vs Prey
# ➔ **Prey**  **Explanation:**  The image primarily features elephants, which are large herbivores and therefore function as **prey** in the context of a predator-prey dynamic. While the image itself does not clearly depict a predator actively hunting them, the presence of elephants places them in the role of the potential prey item in the African savanna ecosystem. The environment suggests a natural setting where large herbivores are vulnerable to predators such as lions, hyenas, or crocodiles (if near water).
#
# [Task L] Nocturnal vs Diurnal
# ➔ **Diurnal**  **Explanation:**  The subject, elephants, are primarily **diurnal**, meaning they are active during the day. While elephants can exhibit some crepuscular (active at dawn/dusk) behavior, the image itself depicts a scene bathed in the warm, bright light of either sunrise or sunset. The presence of strong, direct sunlight and the general activity level suggested by the herd in an open, illuminated landscape strongly indicates a diurnal setting.
#
# [Task M] Domesticated vs Wild Animals
# ➔ **Wild**  **Explanation:** The animals visible in the image are elephants. In their natural habitat, elephants are wild animals. While some elephants can be habituated to human presence (like in tourist settings), they are fundamentally wild creatures, and the context of the image—a natural savanna/bushland environment—strongly suggests they are in their wild state.
#
# ================================================================================
# 🎉 ALL AGENTS COMPLETED TASKS & EXPORTS SUCCESSFULLY!
# ================================================================================
