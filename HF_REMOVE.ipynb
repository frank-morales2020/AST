# %% [markdown]
# <a href="https://colab.research.google.com/github/frank-morales2020/AST/blob/main/HF_REMOVE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata

# Retrieve your token from Colab Secrets
HF_TOKEN = userdata.get('HF_TOKEN')

username='frankmorales2020'

# %%
from huggingface_hub import delete_repo
from google.colab import userdata

# Retrieve your token from Colab Secrets
HF_TOKEN = userdata.get('HF_TOKEN')

try:
    delete_repo(
        repo_id="frankmorales2020/topological-ai-qwen2.5-14B-instruct",
        token=HF_TOKEN,
        repo_type="model"
    )
    print(f"Repository has been deleted.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Repository has been deleted.
